# %% [markdown]
# # Anbefaling av filmer med clustering
#
# Basert på https://www.kaggle.com/airalex/recommend-movie-with-clustering
#
# Her skal vi ved hjelp av clustering foreslå filmer basert på en du liker. Alle filmene tilhører noen sjangre, og vi har informasjon om hvem som har regien, og de viktigste skuespillerne. Vi vil derfor si at to filmer ligner hverandre hvis de har mange sjangre og mange skuespillere til felles.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Innlesing og opprydding i data

# %%
data = pd.read_csv('../../datasets/imdb-5000-movie-dataset/movie_metadata.csv')

to_use = ['genres', 'plot_keywords', 'movie_title', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name', 'imdb_score']
data_use = data[to_use].copy()
data_use['movie_title'] = [i.replace("\xa0","") for i in list(data_use['movie_title'])]

# %%
clean_data = data_use.dropna(axis=0)
clean_data = clean_data.drop_duplicates(['movie_title'])
clean_data = clean_data.reset_index(drop=True)

# %%
people_list = []
merge_columns = ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name']
for i in range(clean_data.shape[0]):
    people_list.append('|'.join(clean_data.iloc[i][col].replace(' ', '_') for col in merge_columns))
clean_data['people'] = people_list

clean_data.head()
# Out:
#                             genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4          Action|Adventure|Sci-Fi
#
#                                        plot_keywords  \
# 0             avatar|future|marine|native|paraplegic
# 1  goddess|marriage ceremony|marriage proposal|pi...
# 2                bomb|espionage|sequel|spy|terrorist
# 3  deception|imprisonment|lawlessness|police offi...
# 4  alien|american civil war|male nipple|mars|prin...
#
#                                 movie_title     actor_1_name  \
# 0                                    Avatar      CCH Pounder
# 1  Pirates of the Caribbean: At World's End      Johnny Depp
# 2                                   Spectre  Christoph Waltz
# 3                     The Dark Knight Rises        Tom Hardy
# 4                               John Carter     Daryl Sabara
#
#        actor_2_name          actor_3_name      director_name  imdb_score  \
# 0  Joel David Moore             Wes Studi      James Cameron         7.9
# 1     Orlando Bloom        Jack Davenport     Gore Verbinski         7.1
# 2      Rory Kinnear      Stephanie Sigman         Sam Mendes         6.8
# 3    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan         8.5
# 4   Samantha Morton          Polly Walker     Andrew Stanton         6.6
#
#                                               people
# 0  CCH_Pounder|Joel_David_Moore|Wes_Studi|James_C...
# 1  Johnny_Depp|Orlando_Bloom|Jack_Davenport|Gore_...
# 2  Christoph_Waltz|Rory_Kinnear|Stephanie_Sigman|...
# 3  Tom_Hardy|Christian_Bale|Joseph_Gordon-Levitt|...
# 4  Daryl_Sabara|Samantha_Morton|Polly_Walker|Andr...

# %% [markdown]
# Som variabler her, skal vi bruke om hver av sjangerne, keywords eller person har noe med filmen å gjøre. Altså 1 hvis den er der, og 0 ellers.
# Avstanden mellom to filmer blir dermed liten hvis de har mange av disse felles.

# %%
from sklearn.feature_extraction.text import CountVectorizer

def token(text):
    return(text.split('|'))

cv_kw=CountVectorizer(max_features=100, tokenizer=token)
keywords = cv_kw.fit_transform(clean_data['plot_keywords'])
keywords_list = ['kw_' + i for i in cv_kw.get_feature_names()]

cv_ge=CountVectorizer(tokenizer=token )
genres = cv_ge.fit_transform(clean_data['genres'])
genres_list = ['genres_' + i for i in cv_ge.get_feature_names()]

cv_pp=CountVectorizer(max_features=100,tokenizer=token )
people = cv_pp.fit_transform(clean_data['people'])
people_list = ['pp_' + i for i in cv_pp.get_feature_names()]

cluster_data = np.hstack([keywords.todense(),genres.todense(),people.todense()*2])
criterion_list = keywords_list+genres_list+people_list

# %% [markdown]
# ## Clustering med K-Means

# %%
from sklearn.cluster import KMeans

mod = KMeans(n_clusters=100)
category = mod.fit_predict(cluster_data)
category_dataframe = pd.DataFrame({'category': category}, index=clean_data['movie_title'])

# %%
clean_data.iloc[list(category_dataframe['category'] == 0)][['genres', 'movie_title', 'people']]
# Out:
#                                      genres  \
# 379                   Biography|Drama|Sport
# 491                         Biography|Drama
# 640               Biography|Drama|Sport|War
# 1158                        Biography|Drama
# 1165                Biography|Drama|Romance
# 1173                  Biography|Drama|Music
# 1218          Biography|Drama|Music|Musical
# 1230            Biography|Crime|Drama|Music
# 1260                Biography|Drama|Romance
# 1292          Biography|Drama|Romance|Sport
# 1301                 Action|Biography|Drama
# 1328           Action|Biography|Drama|Sport
# 1356                    Biography|Drama|War
# 1358                  Biography|Drama|Sport
# 1379                  Biography|Drama|Sport
# 1401                    Biography|Drama|War
# 1417                  Biography|Crime|Drama
# 1542                        Biography|Drama
# 1590                  Biography|Drama|Sport
# 1618                  Biography|Drama|Music
# 1663                Biography|Drama|Romance
# 1670           Action|Biography|Crime|Drama
# 1674                Biography|Drama|Romance
# 1679          Biography|Drama|Music|Romance
# 1856                  Biography|Drama|Sport
# 1909                  Biography|Drama|Sport
# 1936                  Biography|Drama|Sport
# 1967                        Biography|Drama
# 1975          Biography|Drama|Music|Musical
# 1998    Biography|Comedy|Drama|Family|Sport
# ...                                     ...
# 3293          Animation|Biography|Drama|War
# 3343                  Biography|Crime|Drama
# 3344                        Biography|Drama
# 3372            Biography|Drama|Romance|War
# 3383                  Biography|Drama|Music
# 3391                        Biography|Drama
# 3400                  Biography|Drama|Music
# 3403                  Biography|Drama|Sport
# 3409          Biography|Crime|Drama|Western
# 3433                        Biography|Drama
# 3456                  Biography|Drama|Sport
# 3487                  Biography|Drama|Sport
# 3489          Biography|Drama|Music|Romance
# 3542                        Biography|Drama
# 3544                  Biography|Drama|Sport
# 3639        Biography|Drama|Romance|Western
# 3489  Noah_Taylor|Armin_Mueller-Stahl|Nicholas_Bell|...
# 3542  Faye_Dunaway|Xander_Berkeley|Diana_Scarwid|Fra...
# 3544  William_Hurt|Tony_Curran|David_Kross|Stephen_H...
# 3639  James_Coburn|Bob_Dylan|Jason_Robards|Sam_Pecki...
# 3665  Nicolas_Giraud|Clovis_Fouin|Marie_Féret|René_F...
# 3745  Keanu_Reeves|Marg_Helgenberger|Gretchen_Mol|St...
# 3757  Rachel_Hendrix|Cheryl_Ladd|Diana_Vickers|Bruce...
# 3761  Tom_Cullen|Reece_Ritchie|Marama_Corlett|Richar...
# 3813  Corbin_Bleu|Rus_Blackwell|Luis_Antonio|Nathan_...
# 3879  Gary_Oldman|Michael_Wincott|Courtney_Love|Juli...
# 4000    Kelli_Garner|Nick_Stahl|Brad_Renfro|Larry_Clark
# 4052  Paul_Kaye|Neil_Maskell|Kate_Magowan|Michael_Dowse
# 4099  Kristin_Scott_Thomas|Ophelia_Lovibond|Anne-Mar...
# 4141         Bolo_Yeung|Donald_Gibb|Ken_Siu|Newt_Arnold
# 4295  Josh_Swanson|Tom_Hamann|Anthony_Powell|Anthony...
# 4343  Ahna_O'Reilly|Melonie_Diaz|Ariana_Neal|Ryan_Co...
# 4410  Bhole_Baba|Pant_Shirt_Baba|Shriman_Umeshanad_B...
# 4544  Tom_Hardy|James_Lance|Matt_King|Nicolas_Windin...
#
# [102 rows x 3 columns]

# %% [markdown]
# ## Anbefaling av filmer
#
# Vi kan bruke `recommend`-funksjonen til å få filmer som ligner på den vi sender inn. Filmtitlene kommer ut sortert etter IMDb-score.

# %%
def recommend(movie_name, recommend_number=5):
    if movie_name in list(clean_data['movie_title']):
        movie_cluster = category_dataframe.loc[movie_name]['category']
        score = clean_data.iloc[list(category_dataframe['category'] == movie_cluster)][['imdb_score', 'movie_title']]
        sort_score = score.sort_values(['imdb_score'], ascending=[0])
        sort_score = sort_score[sort_score['movie_title'] != movie_name]
        recommend_number = min(sort_score.shape[0], recommend_number)
        recommend_movie = list(sort_score.iloc[range(recommend_number), 1])
        return recommend_movie
    else:
        print('Can\'t find this movie!')

# %%
recommend('Harry Potter and the Prisoner of Azkaban', 10)
# Out:
# ['Monty Python and the Holy Grail',
#  'The Princess Bride',
#  'The Hobbit: The Desolation of Smaug',
#  'The Hobbit: An Unexpected Journey',
#  'Stardust',
#  'Harry Potter and the Goblet of Fire',
#  'The Hobbit: The Battle of the Five Armies',
#  "Harry Potter and the Sorcerer's Stone",
#  'Harry Potter and the Half-Blood Prince',
#  'Harry Potter and the Order of the Phoenix']

# %% [markdown]
# **Oppgave:** Synes du sortering på IMDb-rating er den beste måten å sortere output? Kommer du på et alternativ
#
# Løsning: eks. sortere etter avstand til filmen i clusteret
